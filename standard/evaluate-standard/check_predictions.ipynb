# %%
import os

model_dir = "/shared/3/projects/national-culture/cache/independent/cache/mbart/checkpoint-3750"
predictions_path = os.path.join(model_dir, 'mbart_predictions.txt')
references_path = os.path.join(model_dir, 'mbart_references.txt')

def load_file_lines(file_path):
    with open(file_path, 'r', encoding='utf-8') as file:
        lines = [line.strip() for line in file]
    return lines

predicted_sn = load_file_lines(predictions_path)
reference_en = load_file_lines(references_path)

from datasets import load_dataset

dataset = load_dataset("rahular/itihasa", split="test")
input_en = [example["translation"]["en"] for example in dataset.select(range(len(reference_en)))]
label_sn = [example["translation"]["sn"] for example in dataset.select(range(len(predicted_sn)))]

print("Alignment Check for First 10 Examples:\n")
for i in range(10):
    print(f"Example {i + 1}:")
    print(f"  Input English (input_en): {input_en[i]}")
    print(f"  Reference English (reference_en): {reference_en[i]}")
    print(f"  Label Sanskrit (label_sn): {label_sn[i]}")
    print(f"  Predicted Sanskrit (predicted_sn): {predicted_sn[i]}")
    print()
# Out:
# Alignment Check for First 10 Examples:
#
# Example 1:
#   Input English (input_en): Hearing the words of Viśvāmitra, Rāghava, together with Laksmana, was struck with amazement, and spoke to Viśvāmitra, saying,
#   Reference English (reference_en): Hearing the words of Viśvāmitra, Rāghava, together with Laksmana, was struck with amazement, and spoke to Viśvāmitra, saying,
#   Label Sanskrit (label_sn): विश्वामित्रवचः श्रुत्वा राघवः सहलक्ष्मणः। विस्मयं परमं गत्वा विश्वामित्रमथाब्रवीत्॥
#   Predicted Sanskrit (predicted_sn): विश्वामित्रचश्रुत्वा राघ सहलक्ष्मणः। विस्मयं परमं विश्वामित्रमथाब्रवीत्॥
#
# Example 2:
#   Input English (input_en): O Brāhmaṇa, wonderful is the story that you have recited to us, viz; that of Ganga's sacred dissension and the replenishing of the Ocean.
#   Reference English (reference_en): O Brāhmaṇa, wonderful is the story that you have recited to us, viz; that of Ganga's sacred dissension and the replenishing of the Ocean.
# ...

# %%
model_dir = "/shared/3/projects/national-culture/cache/independent/cache/indictrans/checkpoint-1875"
predictions_path = os.path.join(model_dir, 'indictrans_predictions.txt')
references_path = os.path.join(model_dir, 'indictrans_references.txt')

def load_file_lines(file_path):
    with open(file_path, 'r', encoding='utf-8') as file:
        lines = [line.strip() for line in file]
    return lines

predicted_sn = load_file_lines(predictions_path)
reference_en = load_file_lines(references_path)

from datasets import load_dataset

dataset = load_dataset("rahular/itihasa", split="test")
input_en = [example["translation"]["en"] for example in dataset.select(range(len(reference_en)))]
label_sn = [example["translation"]["sn"] for example in dataset.select(range(len(predicted_sn)))]

print("Alignment Check for First 10 Examples:\n")
for i in range(10):
    print(f"Example {i + 1}:")
    print(f"  Input English (input_en): {input_en[i]}")
    print(f"  Reference English (reference_en): {reference_en[i]}")
    print(f"  Label Sanskrit (label_sn): {label_sn[i]}")
    print(f"  Predicted Sanskrit (predicted_sn): {predicted_sn[i]}")
    print()
# Out:
# Alignment Check for First 10 Examples:
#
# Example 1:
#   Input English (input_en): Hearing the words of Viśvāmitra, Rāghava, together with Laksmana, was struck with amazement, and spoke to Viśvāmitra, saying,
#   Reference English (reference_en): Hearing the words of Viśvāmitra, Rāghava, together with Laksmana, was struck with amazement, and spoke to Viśvāmitra, saying,
#   Label Sanskrit (label_sn): विश्वामित्रवचः श्रुत्वा राघवः सहलक्ष्मणः। विस्मयं परमं गत्वा विश्वामित्रमथाब्रवीत्॥
#   Predicted Sanskrit (predicted_sn): mni_Beng mni_Beng mni_Beng 8 given matters networks held accident.. by 8isted Khaniously 8isted well purchase nationia played same
#
# Example 2:
#   Input English (input_en): O Brāhmaṇa, wonderful is the story that you have recited to us, viz; that of Ganga's sacred dissension and the replenishing of the Ocean.
# ...

# %%
model_dir = "/shared/3/projects/national-culture/cache/independent/cache/indictrans/old-checkpoint-1875"
predictions_path = os.path.join(model_dir, 'indictrans_predictions.txt')
references_path = os.path.join(model_dir, 'indictrans_references.txt')

def load_file_lines(file_path):
    with open(file_path, 'r', encoding='utf-8') as file:
        lines = [line.strip() for line in file]
    return lines

predicted_sn = load_file_lines(predictions_path)
reference_en = load_file_lines(references_path)

from datasets import load_dataset

dataset = load_dataset("rahular/itihasa", split="test")
input_en = [example["translation"]["en"] for example in dataset.select(range(len(reference_en)))]
label_sn = [example["translation"]["sn"] for example in dataset.select(range(len(predicted_sn)))]

print("Alignment Check for First 10 Examples:\n")
for i in range(10):
    print(f"Example {i + 1}:")
    print(f"  Input English (input_en): {input_en[i]}")
    print(f"  Reference English (reference_en): {reference_en[i]}")
    print(f"  Label Sanskrit (label_sn): {label_sn[i]}")
    print(f"  Predicted Sanskrit (predicted_sn): {predicted_sn[i]}")
    print()
# Out:
# Alignment Check for First 10 Examples:
#
# Example 1:
#   Input English (input_en): Hearing the words of Viśvāmitra, Rāghava, together with Laksmana, was struck with amazement, and spoke to Viśvāmitra, saying,
#   Reference English (reference_en): Hearing the words of Viśvāmitra, Rāghava, together with Laksmana, was struck with amazement, and spoke to Viśvāmitra, saying,
#   Label Sanskrit (label_sn): विश्वामित्रवचः श्रुत्वा राघवः सहलक्ष्मणः। विस्मयं परमं गत्वा विश्वामित्रमथाब्रवीत्॥
# ...
